# %%
import requests
from IPython.display import Image, display
from datetime import datetime
import json
import random

class Routine:

    # 1. 랜덤 고양이 사진
    def show_cat(self):
        url = "https://api.thecatapi.com/v1/images/search"
        response = requests.get(url)
        data = response.json()
        cat_url = data[0]['url']

        print("오늘의 고양이 사진:")
        display(Image(url=cat_url))


    # 2. 서울 날씨
    def show_weather(self):
        latitude = 37.5665
        longitude = 126.9780
        today = datetime.utcnow().date()

        url = (
            f"https://api.open-meteo.com/v1/forecast?"
            f"latitude={latitude}&longitude={longitude}"
            f"&daily=temperature_2m_max,temperature_2m_min&timezone=Asia%2FSeoul"
        )

        response = requests.get(url)
        data = response.json()

        dates = data['daily']['time']
        max_temps = data['daily']['temperature_2m_max']
        min_temps = data['daily']['temperature_2m_min']

        for i, date in enumerate(dates):
            if date == str(today):
                print(f"\n 오늘({today}) 서울 날씨")
                print(f"- 최고 기온: {max_temps[i]}°C")
                print(f"- 최저 기온: {min_temps[i]}°C")
                break


    # 3. 오늘의 명언
    def show_quote(self):
        url = "https://zenquotes.io/api/random"
        response = requests.get(url)
        data = response.json()

        quote = data[0]['q']
        author = data[0]['a']

        print("\n 오늘의 명언:")
        print(f'"{quote}" — {author}')


    # 4. 추가 기능 (랜덤 긍정 메시지)
    def extra_feature(self):
        messages = [
            "오늘도 좋은 하루 보내세요",
            "작은 성취가 큰 변화를 만듭니다!",
            "당신은 충분히 잘하고 있어요",
            "오늘은 어제보다 더 나은 하루!"
        ]
        print("\n 추가 메시지:")
        print(random.choice(messages))


    # 전체 루틴 실행
    def routine(self):
        self.show_cat()
        self.show_weather()
        self.show_quote()
        self.extra_feature()


# 실행
morning = Routine()
morning.routine()
# Out:
# 오늘의 고양이 사진:
# <img src="https://cdn2.thecatapi.com/images/b0o.jpg"/>
# C:\Users\user\AppData\Local\Temp\ipykernel_38492\3191854885.py:24: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   today = datetime.utcnow().date()
#  오늘(2026-03-26) 서울 날씨
# - 최고 기온: 14.3°C
# - 최저 기온: 2.3°C
#
#  오늘의 명언:
# "Successful people appreciate where they have come from, but they don't let their past set the tone for their future." — Steve Harvey
#
#  추가 메시지:
# 작은 성취가 큰 변화를 만듭니다!
