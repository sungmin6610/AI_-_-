# %%
print(10)
# Out:
# 10

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Mary's cosmetics")
# Out:
# Mary's cosmetics

# %%
print('신씨가 소리질렀다. "도둑이야!"')
# Out:
# 신씨가 소리질렀다. "도둑이야!"

# %%
print("c:\windows")
# Out:
# c:\windows
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\user\AppData\Local\Temp\ipykernel_3908\2341327506.py:1: SyntaxWarning: invalid escape sequence '\w'
#   print("c:\windows")

# %%
print("안녕하세요. \n만나서\t\t반갑습니다.")
# Out:
# 안녕하세요.
# 만나서		반갑습니다.

# %%
print("오늘은","일요일")
# Out:
# 오늘은 일요일

# %%
print("naver;""kakao;""sk;""samsung;")
# Out:
# naver;kakao;sk;samsung;

# %%
print("naver/""kakao/""sk/""samsung/")
# Out:
# naver/kakao/sk/samsung/

# %%
print("first", end=""); print("second")
# Out:
# firstsecond

# %%
print(5/3)
# Out:
# 1.6666666666666667

# %%
삼성전자 = 50000
총평가금액 = 삼성전자 * 10
print(총평가금액)
# Out:
# 500000

# %%
시가총액 = 2890000000000
현재가 = 50000
PER = 15.79

print(시가총액, type(시가총액))
print(현재가, type(현재가))
print(PER, type(PER))
# Out:
# 2890000000000 <class 'int'>
# 50000 <class 'int'>
# 15.79 <class 'float'>

# %%
s = "hello"
t = "python"
print(s+"!", t)
# Out:
# hello! python

# %%
print(2 + 2 * 3)
# Out:
# 8

# %%
a = 132
print(type(a))
# Out:
# <class 'int'>

# %%
num_str = "720"
num_int = int(num_str)
print(num_int + 1, type(num_int))
# Out:
# 721 <class 'int'>

# %%
num = 100
result = str(num)
print(result, type(result))
# Out:
# 100 <class 'str'>

# %%
data = 15.79
data = float(data)
print(data, type(data))
# Out:
# 15.79 <class 'float'>

# %%
year = 2020
print(int(year)-3)
print(int(year)-2)
print(int(year)-1)
# Out:
# 2017
# 2018
# 2019

# %%
월 = 48584
총금액 = 월 * 36
print(총금액)
# Out:
# 1749024
